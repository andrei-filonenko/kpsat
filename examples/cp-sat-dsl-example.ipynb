// %% [markdown]
// # Resource Scheduling with Constraint Solver DSL
//
// A functional, math-like DSL for constraint programming in Kotlin.
//
// ## Philosophy
//
// - **Declarative over imperative**: Express *what* you want, not *how* to compute it
// - **Functional composition**: Build complex constraints from simple, composable parts
// - **Solver-agnostic**: The DSL abstracts away the underlying solver (CP-SAT)

// %% [markdown]
// ## Setup
//
// Load the solver library (includes DSL, Arrow, and OR-Tools bundled together).
//
// **Build first:** `cd kotlin && ./gradlew :solver:shadowJar`

// %%
// Load the fat JAR with all dependencies bundled
@file:DependsOn("../kotlin/solver/build/libs/solver-all-0.1.0-SNAPSHOT.jar")

import arrow.core.*
import io.github.andreifilonenko.kpsat.dsl.*
import io.github.andreifilonenko.kpsat.solver.*

// Load OR-Tools native library
com.google.ortools.Loader.loadNativeLibraries()

println("Libraries loaded: DSL, Solver, Arrow, OR-Tools")
// Out:
// Libraries loaded: DSL, Solver, Arrow, OR-Tools

// %% [markdown]
// ## Core Concepts
//
// The DSL is built around **expressions** (`Expr`) that form an AST. You compose expressions using familiar operators, then the solver compiles them to constraints.

// %%
// Expressions are created using factory functions from the library
// expr(value) creates a constant, operators build the AST

// Constants
val a = expr(10L)
val b = expr(5L)

// Arithmetic: +, -, *, unary -
println("a + b = ${a + b}")
println("a - b = ${a - b}")
println("a * b = ${a * b}")
println("-a = ${-a}")

// Comparison: eq, neq, lt, leq, gt, geq (return boolean expressions)
println("\na eq b = ${a eq b}")
println("a lt b = ${a lt b}")

// Logical: and, or, not, implies
val p = a gt 5L
val q = b leq 10L
println("\np and q = ${p and q}")
println("p implies q = ${p implies q}")

// Conditional: iif(condition, ifTrue, ifFalse)
println("\niif(p, 100, 0) = ${iif(p, 100L, 0L)}")
// Out:
// a + b = Expr(node=Sum(operands=[Const(value=10), Const(value=5)]))
// a - b = Expr(node=Sub(left=Const(value=10), right=Const(value=5)))
// a * b = Expr(node=Prod(operands=[Const(value=10), Const(value=5)]))
// -a = Expr(node=Neg(operand=Const(value=10)))
//
// a eq b = Expr(node=Eq(left=Const(value=10), right=Const(value=5)))
// a lt b = Expr(node=Lt(left=Const(value=10), right=Const(value=5)))
//
// p and q = Expr(node=And(operands=[Gt(left=Const(value=10), right=Const(value=5)), Leq(left=Const(value=5), right=Const(value=10))]))
// p implies q = Expr(node=Or(operands=[Not(operand=Gt(left=Const(value=10), right=Const(value=5))), Leq(left=Const(value=5), right=Const(value=10))]))
//
// iif(p, 100, 0) = Expr(node=If(condition=Gt(left=Const(value=10), right=Const(value=5)), ifTrue=Const(value=100), ifFalse=Const(value=0)))

// %% [markdown]
// ## Functional Aggregations
//
// Use `sum`, `forAll`, `exists` to transform collections into constraints. These compose naturally with Kotlin's collection functions.

// %%
// Aggregations work with any Iterable
val items = listOf(1, 2, 3, 4, 5)

// sum: aggregate values
val totalCost = sum(items) { expr(it.toLong()) * expr(10L) }
println("sum with selector: $totalCost")

// forAll: universal quantifier (AND over collection)
val allPositive = forAll(items) { expr(it.toLong()) gt 0L }
println("forAll (item > 0): $allPositive")

// exists: existential quantifier (OR over collection)
val hasLarge = exists(items) { expr(it.toLong()) gt 3L }
println("exists (item > 3): $hasLarge")

// Compose with Kotlin collection functions
val filtered = items
    .filter { it > 2 }
    .map { expr(it.toLong()) }
    .let { sum(it) }
println("sum of filtered: $filtered")
// Out:
// sum with selector: Expr(node=Sum(operands=[Prod(operands=[Const(value=1), Const(value=10)]), Prod(operands=[Const(value=2), Const(value=10)]), Prod(operands=[Const(value=3), Const(value=10)]), Prod(operands=[Const(value=4), Const(value=10)]), Prod(operands=[Const(value=5), Const(value=10)])]))
// forAll (item > 0): Expr(node=And(operands=[Gt(left=Const(value=1), right=Const(value=0)), Gt(left=Const(value=2), right=Const(value=0)), Gt(left=Const(value=3), right=Const(value=0)), Gt(left=Const(value=4), right=Const(value=0)), Gt(left=Const(value=5), right=Const(value=0))]))
// exists (item > 3): Expr(node=Or(operands=[Gt(left=Const(value=1), right=Const(value=3)), Gt(left=Const(value=2), right=Const(value=3)), Gt(left=Const(value=3), right=Const(value=3)), Gt(left=Const(value=4), right=Const(value=3)), Gt(left=Const(value=5), right=Const(value=3))]))
// sum of filtered: Expr(node=Sum(operands=[Const(value=3), Const(value=4), Const(value=5)]))

// %% [markdown]
// ## Building Models with the Solver
//
// The `ConstraintSolverBuilder` provides a functional, declarative API. Chain methods to define your model—no mutable state exposed.

// %%
// Pure functional model definition - no side effects until solve()
// The builder pattern chains immutably

val simpleModel = ConstraintSolverBuilder()
    .timeLimit(30)
    .numWorkers(4)
    
    // Variables: lambda with explicit scope parameter
    .variables { scope ->
        mapOf(
            "x" to scope.int("x", 0, 10),
            "y" to scope.int("y", 0, 10)
        )
    }
    
    // Hard constraint: must be satisfied
    .hard("sum_equals_15") { scope, vars ->
        (vars["x"]!! + vars["y"]!!) eq 15L
    }
    
    // Maximize the product
    .maximize("product", priority = 0) { scope, vars ->
        vars["x"]!! * vars["y"]!!
    }
    
    .build()

println("Model built (nothing solved yet - lazy evaluation)")
// Out:
// Model built (nothing solved yet - lazy evaluation)

// %% [markdown]
// ## Solving and Handling Results
//
// Call `solve()` to run the solver and get results.

// %%
// Solve returns a SolveResult
val result = simpleModel.solve()

// Pattern match on status
when (result.status) {
    SolveStatus.OPTIMAL -> {
        println("✓ Optimal solution found!")
        println("  Objective value: ${result.objectiveValue}")
    }
    SolveStatus.FEASIBLE -> {
        println("~ Feasible solution (may not be optimal)")
    }
    SolveStatus.INFEASIBLE -> {
        println("✗ No feasible solution exists")
    }
    else -> {
        println("? Status: ${result.status}")
    }
}

// Extract values
if (result.hasSolution) {
    val x = result.scope.value(result.variables["x"]!!).getOrNull()
    val y = result.scope.value(result.variables["y"]!!).getOrNull()
    println("  x = $x, y = $y")
}
// Out:
// ✓ Optimal solution found!
//   Objective value: 56.0
//   x = 8, y = 7

// %% [markdown]
// ## Summary
//
// **What we demonstrated:**
//
// | Component | Purpose |
// |-----------|--------|
// | `Expr` | Composable expression with operator overloads |
// | `sum`, `forAll`, `exists` | Functional aggregations |
// | `ConstraintSolverBuilder` | Fluent, functional model definition |
// | `SolveResult` | Solution status and value extraction |
//
// **DSL Operators:**
//
// - **Arithmetic**: `+`, `-`, `*`, unary `-`
// - **Comparison**: `eq`, `neq`, `lt`, `leq`, `gt`, `geq`
// - **Logical**: `and`, `or`, `not`, `implies`
// - **Conditional**: `iif(cond, ifTrue, ifFalse)`

// %% [markdown]
// ## Next Steps
//
// **Build from source:**
//
// ```bash
// cd kotlin/
// ./gradlew :solver:shadowJar
// ```
//
// **Use as a library:**
//
// ```kotlin
// dependencies {
//     implementation("io.github.andreifilonenko:solver:0.1.0")
// }
// ```

// %% [markdown]
// ## Classic Example: N-Queens Problem
//
// The N-Queens puzzle asks: how can you place N chess queens on an N×N board so that no two queens threaten each other?
//
// This is a classic constraint satisfaction problem with:
// - **N decision variables**: one for each column, indicating which row the queen is placed
// - **Hard constraints**:
//   - All rows must be different (no two queens on same row)
//   - All diagonals must be different (no two queens on same diagonal)

// %%
// N-Queens: Place N queens on an NxN board so no two attack each other
val N = 8

val queensModel = ConstraintSolverBuilder()
    .timeLimit(60)
    .numWorkers(4)
    
    // Variables: queens[i] = row of queen in column i
    .variables { scope ->
        (0 until N).associate { col ->
            "q$col" to scope.int("queen_$col", 0, (N - 1).toLong())
        }
    }
    
    // Hard: All rows must be different (no two queens on same row)
    .hard("different_rows") { _, vars ->
        val queens = (0 until N).map { vars["q$it"]!! }
        allDifferent(queens)
    }
    
    // Hard: No two queens on the same diagonal (↘ direction)
    // queens[i] + i must be different for all i
    .hard("different_diag1") { _, vars ->
        val diag1 = (0 until N).map { i -> vars["q$i"]!! + i.toLong() }
        allDifferent(diag1)
    }
    
    // Hard: No two queens on the same diagonal (↗ direction)
    // queens[i] - i must be different for all i
    .hard("different_diag2") { _, vars ->
        val diag2 = (0 until N).map { i -> vars["q$i"]!! - i.toLong() }
        allDifferent(diag2)
    }
    
    .build()

println("$N-Queens model built")
// Out:
// 8-Queens model built

// %%
// Solve and visualize the board
val queensResult = queensModel.solve()

if (queensResult.hasSolution) {
    println("✓ Solution found for $N-Queens!\n")
    
    // Extract queen positions
    val positions = (0 until N).map { col ->
        queensResult.scope.value(queensResult.variables["q$col"]!!).getOrNull()!!.toInt()
    }
    
    // Print the board
    println("  " + (0 until N).joinToString(" ") { ('a' + it).toString() })
    for (row in 0 until N) {
        print("${N - row} ")
        for (col in 0 until N) {
            print(if (positions[col] == row) "♛ " else "· ")
        }
        println()
    }
    println()
    println("Queen positions (column → row): ${positions.mapIndexed { c, r -> "${('a' + c)}${N - r}" }}")
} else {
    println("✗ No solution found: ${queensResult.status}")
}
// Out:
// ✓ Solution found for 8-Queens!
//
//   a b c d e f g h
// 8 · · ♛ · · · · ·
// 7 · · · · · · ♛ ·
// 6 · ♛ · · · · · ·
// 5 · · · · · · · ♛
// 4 · · · · ♛ · · ·
// 3 ♛ · · · · · · ·
// 2 · · · ♛ · · · ·
// 1 · · · · · ♛ · ·
//
// Queen positions (column → row): [a3, b6, c8, d2, e4, f1, g7, h5]

// %% [markdown]
// ## Resource-Constrained Project Scheduling (RCPSP)
//
// A real-world example demonstrating the DSL for resource scheduling optimization.
//
// ### Problem Definition
//
// The **Resource-Constrained Project Scheduling Problem (RCPSP)** is defined as follows:
//
// **Sets and Indices:**
// - $V = \{0, 1, \ldots, N, N+1\}$ — Set of activities (0 = project start, N+1 = project end)
// - $\mathcal{R} = \{1, \ldots, m\}$ — Set of renewable resources
// - $T = \{0, 1, \ldots, H\}$ — Time horizon (discretized to days)
// - $E \subseteq V \times V$ — Set of precedence arcs (activity dependencies)
//
// **Parameters:**
// - $p_j$ — Processing time (duration in hours) of activity $j$
// - $r_{j,k}$ — Amount of resource $k$ required by activity $j$
// - $R_k$ — Capacity of resource $k$ (hours per day)
// - $D_P$ — Project deadline (from project endDate)
// - $c_j^{\text{comm}}$ — Commercial rate for activity $j$
// - $c_k^{\text{res}}$ — Hourly cost of resource $k$
//
// **Decision Variables:**
// - $S_j \in \{0, 1, \ldots, H\}$ — Start time (date index) of activity $j$
// - $x_{j,k} \in \{0,1\}$ — Assignment of activity $j$ to resource $k$
//
// ### Hard Constraints
//
// **Precedence:** If activity $i$ must complete before $j$ starts:
// $$S_i + p_i \leq S_j \quad \forall (i, j) \in E$$
//
// **Resource Capacity:** At each time $t$, resource usage cannot exceed capacity:
// $$\sum_{j \in A_t} r_{j,k} \leq R_k \quad \forall k \in \mathcal{R}, \forall t \in T$$
//
// **Project Deadline:** All activities must complete before project deadline:
// $$S_j + p_j \leq D_P \quad \forall j \in V_P$$
//
// **Skill Requirements:** Resource must have required skills:
// $$x_{j,k} = 1 \Rightarrow k \in \text{QualifiedResources}(j)$$
//
// ### Objectives (Lexicographic)
//
// **Priority 2 — Minimize Makespan:**
// $$\min \max_{j \in V} (S_j + p_j)$$
//
// **Priority 1 — Maximize Margin:**
// $$\max \sum_{j \in V} (c_j^{\text{comm}} - c_{r(j)}^{\text{res}}) \cdot p_j$$
//
// ### Soft Constraints (Penalties)
//
// **Resource Consistency:** Penalize switching resources within same activity
// $$\min \sum_{(u,v) \in \text{SameActivity}} \mathbb{1}[r(u) \neq r(v)]$$
//
// **Consecutive Days:** Penalize gaps in resource assignments

// %%
// Data classes for RCPSP domain model
import com.fasterxml.jackson.databind.ObjectMapper
import com.fasterxml.jackson.dataformat.yaml.YAMLFactory
import com.fasterxml.jackson.module.kotlin.KotlinModule
import com.fasterxml.jackson.datatype.jsr310.JavaTimeModule
import com.fasterxml.jackson.annotation.JsonProperty
import java.io.File
import java.time.LocalDate
import java.time.DayOfWeek

data class Department(val id: String, val name: String)

data class Position(
    val id: String,
    val name: String,
    val skillLevel: String,
    val hourlyRate: Double
)

data class BankHolidaySet(
    val id: String,
    val name: String,
    val holidays: List<LocalDate> = emptyList()
)

data class Resource(
    val id: Long,
    val name: String,
    val departmentId: String,
    val positionId: String,
    val skills: List<String> = emptyList(),
    val bankHolidaySetId: String,
    val weeklyAvailability: Map<String, Int> = emptyMap()
)

data class Project(
    val id: Long,
    val name: String,
    val projectCode: String,
    val departmentId: String,
    val startDate: LocalDate?,
    val endDate: LocalDate?,  // Project deadline
    val priority: Int
)

data class Activity(
    val id: Long,
    val code: String,
    val name: String,
    val order: Int,
    val projectId: Long,
    val dependencies: List<Long> = emptyList(),  // Predecessor activity IDs
    val estimatedHours: Int,
    val rate: Double,
    val isCommercialRate: Boolean,
    val budgetNumbers: Int? = null,
    val requestDepartmentId: String? = null,
    val requestPositionId: String? = null,
    val requestSkillLevel1: String? = null,
    val requestSkillLevel2: String? = null,
    val requestSkillLevel3: String? = null
)

// Work unit: 1 hour of work to be scheduled
data class WorkUnit(
    val id: Long,
    val activityId: Long,
    val projectId: Long
)

// Complete data model
data class SchedulingData(
    val departments: List<Department> = emptyList(),
    val positions: List<Position> = emptyList(),
    val bankHolidaySets: List<BankHolidaySet> = emptyList(),
    val resources: List<Resource> = emptyList(),
    val projects: List<Project> = emptyList(),
    val activities: List<Activity> = emptyList()
)

println("Data classes defined")
// Out:
// Data classes defined

// %%
// Load scheduling data from YAML
val mapper = ObjectMapper(YAMLFactory()).apply {
    registerModule(KotlinModule.Builder().build())
    registerModule(JavaTimeModule())
}

val data = mapper.readValue(File("data.yaml"), SchedulingData::class.java)

println("Loaded scheduling data:")
println("  Departments: ${data.departments.size}")
println("  Positions: ${data.positions.size}")
println("  Resources: ${data.resources.size}")
println("  Projects: ${data.projects.size}")
println("  Activities: ${data.activities.size}")

// Show activity dependencies
println("\nActivity dependencies:")
data.activities.forEach { act ->
    val deps = if (act.dependencies.isEmpty()) "none" 
               else act.dependencies.joinToString(", ") { depId -> 
                   data.activities.find { it.id == depId }?.name ?: depId.toString() 
               }
    println("  ${act.name} → depends on: $deps")
}
// Out:
// Loaded scheduling data:
//   Departments: 4
//   Positions: 8
//   Resources: 10
//   Projects: 10
//   Activities: 32
//
// Activity dependencies:
//   Architecture Design → depends on: none
//   API Development → depends on: Architecture Design
//   Integration Testing → depends on: API Development
//   Wireframing → depends on: none
//   Visual Design → depends on: Wireframing
//   Prototyping → depends on: Visual Design
//   Database Schema → depends on: none
//   Frontend Implementation → depends on: Database Schema
//   User Interviews → depends on: none
//   Data Analysis → depends on: User Interviews
//   Requirements Analysis → depends on: none
//   Backend Integration → depends on: Requirements Analysis
//   Security Audit → depends on: Backend Integration
//   Production Deployment → depends on: Security Audit
//   UX Research → depends on: none
//   Design System → depends on: UX Research
//   Component Library → depends on: Design System
// ...

// %%
// Setup problem: generate work units and compute date range

// Generate date range from project boundaries
val minDate = data.projects.mapNotNull { it.startDate }.minOrNull() ?: LocalDate.now()
val maxDate = data.projects.mapNotNull { it.endDate }.maxOrNull() ?: minDate.plusDays(30)

// Create weekday date list (excluding weekends)
val allDates = generateSequence(minDate) { it.plusDays(1) }
    .takeWhile { !it.isAfter(maxDate) }
    .filter { it.dayOfWeek !in listOf(DayOfWeek.SATURDAY, DayOfWeek.SUNDAY) }
    .toList()

val dateToIndex = allDates.mapIndexed { idx, date -> date to idx.toLong() }.toMap()
val indexToDate = allDates.mapIndexed { idx, date -> idx.toLong() to date }.toMap()

// Generate work units (1 hour each)
var unitId = 1L
val workUnits = data.activities.flatMap { activity ->
    (1..activity.estimatedHours).map { 
        WorkUnit(unitId++, activity.id, activity.projectId)
    }
}

// Build lookup maps
val activityById = data.activities.associateBy { it.id }
val projectById = data.projects.associateBy { it.id }
val resourceById = data.resources.associateBy { it.id }
val positionById = data.positions.associateBy { it.id }

// Compute qualified resources per activity (skill matching)
val qualifiedResourcesByActivity = data.activities.associate { activity ->
    val requiredSkills = listOfNotNull(
        activity.requestSkillLevel1,
        activity.requestSkillLevel2,
        activity.requestSkillLevel3
    )
    val qualified = if (requiredSkills.isEmpty()) {
        data.resources.map { it.id }
    } else {
        data.resources.filter { res -> 
            requiredSkills.any { skill -> skill in res.skills }
        }.map { it.id }
    }
    activity.id to qualified
}

println("Problem setup complete:")
println("  Date range: $minDate to $maxDate (${allDates.size} working days)")
println("  Work units: ${workUnits.size} hours to schedule")
println("  Dependencies: ${data.activities.sumOf { it.dependencies.size }} precedence arcs")
// Out:
// Problem setup complete:
//   Date range: 2025-09-22 to 2025-10-31 (30 working days)
//   Work units: 638 hours to schedule
//   Dependencies: 22 precedence arcs

// %% [markdown]
// ### Building the RCPSP Model
//
// We'll build a complete scheduling model with:
// - **Hard constraints**: Precedence, resource capacity, project deadlines, skill requirements
// - **Objectives**: Minimize makespan, maximize margin
// - **Soft constraints**: Resource consistency, consecutive days

// %%
// Build the RCPSP model using the DSL
val numResources = data.resources.size
val numDates = allDates.size
val MAX_HOURS_PER_DAY = 8L  // Default daily capacity

// Compute project deadline indices
val projectDeadlineIndex = data.projects.associate { proj ->
    proj.id to (dateToIndex[proj.endDate] ?: (numDates - 1).toLong())
}

// Build list of dependency pairs for precedence constraints
val dependencyPairs = data.activities.flatMap { act ->
    act.dependencies.map { predId -> predId to act.id }
}

// Precompute resource availability per (resource, day of week)
val resourceDailyCapacity = data.resources.mapIndexed { resIdx, resource ->
    val capacityByDay = DayOfWeek.entries.associate { dow ->
        dow to (resource.weeklyAvailability[dow.name] ?: MAX_HOURS_PER_DAY.toInt()).toLong()
    }
    resIdx to capacityByDay
}.toMap()

// Group work units by activity for easier constraint building
val workUnitsByActivity = workUnits.groupBy { it.activityId }

// Pre-compute minimum theoretical days per activity (for fragmentation penalty)
val minDaysPerActivity = data.activities.associate { act ->
    act.id to ((act.estimatedHours + 7) / 8)  // ceiling division: minimum days needed
}

// Pre-compute consecutive unit pairs within each activity (for resource consistency)
data class UnitPair(val u1: WorkUnit, val u2: WorkUnit)
val consecutiveUnitPairs = data.activities.flatMap { act ->
    workUnits.filter { it.activityId == act.id }.zipWithNext().map { (u1, u2) -> UnitPair(u1, u2) }
}

val rcpspModel = ConstraintSolverBuilder()
    .timeLimit(120)
    .numWorkers(8)
    .logProgress(true)
    .variables { scope ->
        val vars = mutableMapOf<String, Expr>()
        workUnits.forEach { unit ->
            vars["res_${unit.id}"] = scope.int("res_${unit.id}", 0, (numResources - 1).toLong())
            vars["date_${unit.id}"] = scope.int("date_${unit.id}", 0, (numDates - 1).toLong())
        }
        data.activities.forEach { act ->
            vars["act_start_${act.id}"] = scope.int("act_start_${act.id}", 0, (numDates - 1).toLong())
            vars["act_end_${act.id}"] = scope.int("act_end_${act.id}", 0, (numDates - 1).toLong())
        }
        
        vars
    }
    .hard("precedence") { _, vars ->
        forAll(dependencyPairs) { (predId, succId) ->
            val predEnd = vars["act_end_$predId"]!!
            val succStart = vars["act_start_$succId"]!!
            predEnd lt succStart
        }
    }
    .hard("resource_capacity") { _, vars ->
        forAll(0 until numResources) { resIdx ->
            forAll(0 until numDates) { dateIdx ->
                val date = allDates[dateIdx]
                val capacity = resourceDailyCapacity[resIdx]?.get(date.dayOfWeek) ?: MAX_HOURS_PER_DAY
                
                val countExpr = sum(workUnits) { unit ->
                    val isThisRes = vars["res_${unit.id}"]!! eq resIdx.toLong()
                    val isThisDate = vars["date_${unit.id}"]!! eq dateIdx.toLong()
                    iif(isThisRes and isThisDate, 1L, 0L)
                }
                
                countExpr leq capacity
            }
        }
    }
    .hard("activity_bounds") { _, vars ->
        forAll(data.activities) { act ->
            val actUnits = workUnits.filter { it.activityId == act.id }
            val actStart = vars["act_start_${act.id}"]!!
            val actEnd = vars["act_end_${act.id}"]!!
            
            forAll(actUnits) { unit ->
                val unitDate = vars["date_${unit.id}"]!!
                (actStart leq unitDate) and (unitDate leq actEnd)
            }
        }
    }
    .hard("project_deadline") { _, vars ->
        forAll(data.activities) { act ->
            val deadline = projectDeadlineIndex[act.projectId] ?: (numDates - 1).toLong()
            vars["act_end_${act.id}"]!! leq deadline
        }
    }
    .hard("skill_requirements") { _, vars ->
        forAll(workUnits) { unit ->
            val qualified = qualifiedResourcesByActivity[unit.activityId] ?: emptyList()
            if (qualified.isNotEmpty() && qualified.size < numResources) {
                val qualifiedIndices = qualified.mapNotNull { resId -> 
                    data.resources.indexOfFirst { it.id == resId }.takeIf { it >= 0 }?.toLong()
                }.toLongArray()
                vars["res_${unit.id}"]!! inDomain qualifiedIndices
            } else {
                expr(1L) eq 1L  // Always true - no restriction
            }
        }
    }
    .soft(
        name = "activity_fragmentation",
        weight = 5,
        priority = 1
    ) { _, vars ->
        sum(data.activities) { act ->
            val span = vars["act_end_${act.id}"]!! - vars["act_start_${act.id}"]!! + 1L
            val minDays = minDaysPerActivity[act.id]!!.toLong()
            // Penalty = days beyond minimum
            span - minDays
        }
    }
    .soft(
        name = "resource_consistency",
        weight = 10,
        priority = 1
    ) { _, vars ->
        // Count pairs where resource differs between consecutive work units
        sum(consecutiveUnitPairs) { pair ->
            val different = vars["res_${pair.u1.id}"]!! neq vars["res_${pair.u2.id}"]!!
            different  // 1 if different, 0 if same
        }
    }
    .maximize("contiguous_blocks", priority = 1) { _, vars ->
        sum(data.activities) { act ->
            val actUnits = workUnits.filter { it.activityId == act.id }
            if (actUnits.size <= 1) {
                expr(0L)
            } else {
                // For each consecutive pair of units in this activity
                sum(0 until actUnits.size - 1) { i ->
                    val u1 = actUnits[i]
                    val u2 = actUnits[i + 1]
                    val res1 = vars["res_${u1.id}"]!!
                    val res2 = vars["res_${u2.id}"]!!
                    val date1 = vars["date_${u1.id}"]!!
                    val date2 = vars["date_${u2.id}"]!!
                    
                    // Reward +10 for same resource
                    val sameResource = iif(res1 eq res2, 10L, 0L)
                    
                    // Reward +5 for same date, +3 for adjacent date
                    val dateDiff = iif(date1 leq date2, date2 - date1, date1 - date2)
                    val dateBonus = iif(dateDiff eq 0L, 5L, iif(dateDiff eq 1L, 3L, 0L))
                    
                    sameResource + dateBonus
                }
            }
        }
    }
    .minimize("makespan", priority = 2) { _, vars ->
        max(data.activities.map { vars["act_end_${it.id}"]!! })
    }
    .build()

// Count consecutive pairs for the contiguous blocks objective
val consecutivePairs = data.activities.sumOf { act ->
    val actUnits = workUnits.filter { it.activityId == act.id }
    maxOf(0, actUnits.size - 1)
}

println("RCPSP model built with ${workUnits.size} work units")
println("  Hard constraints:")
println("    - Resource capacity: max $MAX_HOURS_PER_DAY hours/day per resource")
println("    - Precedence: ${dependencyPairs.size} activity dependencies")
println("    - Skill requirements: activities matched to qualified resources")
println("  Soft constraints:")
println("    - Activity fragmentation: penalize span beyond minimum days (weight=5)")
println("    - Resource consistency: penalize resource switches within activity (weight=10)")
println("  Objectives:")
println("    - Priority 2: Minimize makespan")
println("    - Priority 1: Maximize contiguous blocks ($consecutivePairs consecutive pairs)")
// Out:
// RCPSP model built with 638 work units
//   Hard constraints:
//     - Resource capacity: max 8 hours/day per resource
//     - Precedence: 22 activity dependencies
//     - Skill requirements: activities matched to qualified resources
//   Soft constraints:
//     - Activity fragmentation: penalize span beyond minimum days (weight=5)
//     - Resource consistency: penalize resource switches within activity (weight=10)
//   Objectives:
//     - Priority 2: Minimize makespan
//     - Priority 1: Maximize contiguous blocks (606 consecutive pairs)

// %%
// Solve the model
println("Solving RCPSP model...")
val rcpspResult = rcpspModel.solve()

when (rcpspResult.status) {
    SolveStatus.OPTIMAL -> println("✓ Optimal solution found!")
    SolveStatus.FEASIBLE -> println("~ Feasible solution found (may not be optimal)")
    SolveStatus.INFEASIBLE -> println("✗ No feasible solution - constraints cannot be satisfied")
    else -> println("? Status: ${rcpspResult.status}")
}

if (rcpspResult.hasSolution) {
    println("\nObjective value: ${rcpspResult.objectiveValue}")
    
    // Extract solution
    data class Assignment(val unitId: Long, val resourceId: Long, val dateIdx: Long, val activityId: Long, val projectId: Long)
    
    val assignments = workUnits.map { unit ->
        Assignment(
            unit.id,
            rcpspResult.scope.value(rcpspResult.variables["res_${unit.id}"]!!).getOrNull()!!,
            rcpspResult.scope.value(rcpspResult.variables["date_${unit.id}"]!!).getOrNull()!!,
            unit.activityId,
            unit.projectId
        )
    }
    
    // Summary by activity
    println("\nActivity schedule:")
    data.activities.forEach { act ->
        val actAssignments = assignments.filter { it.activityId == act.id }
        val startDate = actAssignments.minOfOrNull { indexToDate[it.dateIdx] ?: minDate }
        val endDate = actAssignments.maxOfOrNull { indexToDate[it.dateIdx] ?: maxDate }
        val resources = actAssignments.map { it.resourceId }.distinct()
            .map { resId -> data.resources.find { it.id == resId + 1 }?.name ?: "R$resId" }
        println("  ${act.name}: $startDate → $endDate (${actAssignments.size}h) by ${resources.joinToString()}")
    }
}
// Out:
// Solving RCPSP model...
// ~ Feasible solution found (may not be optimal)
//
// Objective value: -5027.0
//
// Activity schedule:
//   Architecture Design: 2025-09-22 → 2025-09-24 (13h) by Felix Moonstone
//   API Development: 2025-10-02 → 2025-10-10 (18h) by Nova Brightwell, Echo Silverstream
//   Integration Testing: 2025-10-14 → 2025-10-15 (11h) by Felix Moonstone, Echo Silverstream, Nova Brightwell
//   Wireframing: 2025-09-29 → 2025-10-01 (14h) by River Ashford
//   Visual Design: 2025-10-08 → 2025-10-10 (19h) by Luna Silverstone, Aurora Nightshade
//   Prototyping: 2025-10-14 → 2025-10-15 (12h) by Atlas Thornfield, River Ashford
//   Database Schema: 2025-09-22 → 2025-09-30 (17h) by Felix Moonstone, Nova Brightwell
//   Frontend Implementation: 2025-10-08 → 2025-10-15 (22h) by Echo Silverstream, Felix Moonstone
//   User Interviews: 2025-10-07 → 2025-10-14 (13h) by Aurora Nightshade
//   Data Analysis: 2025-10-15 → 2025-10-15 (7h) by Luna Silverstone
// ...

// %% [markdown]
// ### Visualizing the Schedule
//
// HTML-rendered calendars and Gantt charts for analyzing the solution.

// %%
// Resource Calendar - shows work assignments per resource per day
if (rcpspResult.hasSolution) {
    data class VisAssignment(val resourceIdx: Long, val dateIdx: Long, val activityId: Long, val projectId: Long)
    
    val visAssignments = workUnits.map { unit ->
        VisAssignment(
            rcpspResult.scope.value(rcpspResult.variables["res_${unit.id}"]!!).getOrNull()!!,
            rcpspResult.scope.value(rcpspResult.variables["date_${unit.id}"]!!).getOrNull()!!,
            unit.activityId,
            unit.projectId
        )
    }
    
    // Filter to only dates with bookings
    val maxDateIdx = visAssignments.maxOfOrNull { it.dateIdx }?.toInt() ?: 0
    val displayDates = allDates.take(maxDateIdx + 1)
    
    val byResourceDate = visAssignments.groupBy { it.resourceIdx to it.dateIdx }
    
    val projectColors = data.projects.mapIndexed { idx, proj ->
        val hue = (idx * 360 / data.projects.size)
        proj.id to "hsl($hue, 70%, 80%)"
    }.toMap()
    
    val html = buildString {
        append("<div style='font-family: -apple-system, BlinkMacSystemFont, sans-serif;'>")
        append("<h4>Resource Calendar</h4>")
        append("<table style='border-collapse: collapse; font-size: 11px;'>")
        
        // Header
        append("<tr>")
        append("<th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa;'>Resource</th>")
        displayDates.forEach { date ->
            append("<th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 50px;'>")
            append("${date.dayOfWeek.toString().take(3)}<br/>${date.monthValue}/${date.dayOfMonth}")
            append("</th>")
        }
        append("</tr>")
        
        // Resource rows
        data.resources.forEachIndexed { resIdx, resource ->
            append("<tr>")
            append("<td style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; font-weight: bold;'>${resource.name}</td>")
            
            displayDates.forEachIndexed { dateIdx, _ ->
                append("<td style='border: 1px solid #ddd; padding: 4px; vertical-align: top;'>")
                
                val dayAssignments = byResourceDate[resIdx.toLong() to dateIdx.toLong()] ?: emptyList()
                dayAssignments.groupBy { it.activityId }.forEach { (actId, units) ->
                    val activity = activityById[actId]
                    val project = projectById[units.first().projectId]
                    val color = projectColors[project?.id] ?: "#e0e0e0"
                    append("<div style='padding: 2px 4px; margin: 1px; border-radius: 3px; font-size: 10px; background: $color;'>")
                    append("${activity?.code?.takeLast(3) ?: actId} ${units.size}h")
                    append("</div>")
                }
                append("</td>")
            }
            append("</tr>")
        }
        append("</table>")
        
        // Legend
        append("<div style='margin-top: 10px;'><b>Projects:</b> ")
        data.projects.forEach { proj ->
            val color = projectColors[proj.id] ?: "#e0e0e0"
            append("<span style='display: inline-block; padding: 2px 8px; margin: 2px; background: $color; border-radius: 3px;'>${proj.projectCode}</span>")
        }
        append("</div></div>")
    }
    
    DISPLAY(HTML(html))
} else {
    println("No solution to visualize")
}
// Out:
// <div style='font-family: -apple-system, BlinkMacSystemFont, sans-serif;'><h4>Resource Calendar</h4><table style='border-collapse: collapse; font-size: 11px;'><tr><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa;'>Resource</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 50px;'>MON<br/>9/22</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 50px;'>TUE<br/>9/23</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 50px;'>WED<br/>9/24</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 50px;'>THU<br/>9/25</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 50px;'>FRI<br/>9/26</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 50px;'>MON<br/>9/29</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 50px;'>TUE<br/>9/30</th><th style='borde
// ...

// %%
// Project Calendar - shows activity assignments per project per day
if (rcpspResult.hasSolution) {
    data class ProjAssignment(val resourceIdx: Long, val dateIdx: Long, val activityId: Long, val projectId: Long)
    
    val projAssignments = workUnits.map { unit ->
        ProjAssignment(
            rcpspResult.scope.value(rcpspResult.variables["res_${unit.id}"]!!).getOrNull()!!,
            rcpspResult.scope.value(rcpspResult.variables["date_${unit.id}"]!!).getOrNull()!!,
            unit.activityId,
            unit.projectId
        )
    }
    
    // Filter to only dates with bookings
    val maxDateIdx = projAssignments.maxOfOrNull { it.dateIdx }?.toInt() ?: 0
    val displayDates = allDates.take(maxDateIdx + 1)
    
    val resourceColors = data.resources.mapIndexed { idx, res ->
        res.id to "hsl(${idx * 360 / data.resources.size}, 60%, 75%)"
    }.toMap()
    
    val html = buildString {
        append("<div style='font-family: -apple-system, BlinkMacSystemFont, sans-serif;'>")
        append("<h4>Project Calendar</h4>")
        append("<table style='border-collapse: collapse; font-size: 11px;'>")
        
        // Header
        append("<tr>")
        append("<th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa;'>Project</th>")
        append("<th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa;'>Activity</th>")
        displayDates.forEach { date ->
            append("<th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 45px;'>")
            append("${date.dayOfWeek.toString().take(3)}<br/>${date.monthValue}/${date.dayOfMonth}")
            append("</th>")
        }
        append("</tr>")
        
        // Project rows
        data.projects.forEach { project ->
            val projectActivities = data.activities.filter { it.projectId == project.id }.sortedBy { it.order }
            var firstRow = true
            
            projectActivities.forEach { activity ->
                append("<tr>")
                
                if (firstRow) {
                    append("<td rowspan='${projectActivities.size}' style='border: 1px solid #ddd; padding: 4px; background: #e8f4f8; font-weight: bold;'>")
                    append("<b>${project.projectCode}</b><br/>${project.name}")
                    append("</td>")
                    firstRow = false
                }
                
                append("<td style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa;'>")
                append("${activity.code.takeLast(3)}<br/><small>${activity.name}</small>")
                append("</td>")
                
                val actAssignments = projAssignments.filter { it.activityId == activity.id }
                val byDate = actAssignments.groupBy { it.dateIdx }
                
                displayDates.forEachIndexed { dateIdx, _ ->
                    append("<td style='border: 1px solid #ddd; padding: 2px; vertical-align: top;'>")
                    
                    val dayAssignments = byDate[dateIdx.toLong()] ?: emptyList()
                    dayAssignments.groupBy { it.resourceIdx }.forEach { (resIdx, units) ->
                        val resource = data.resources.getOrNull(resIdx.toInt())
                        val initials = resource?.name?.split(" ")?.map { it.first() }?.joinToString("") ?: "?"
                        val color = resourceColors[resource?.id] ?: "#e0e0e0"
                        append("<div style='padding: 2px; margin: 1px; border-radius: 2px; font-size: 9px; background: $color;' title='${resource?.name ?: ""}'>")
                        append("<b>$initials</b> ${units.size}h")
                        append("</div>")
                    }
                    append("</td>")
                }
                append("</tr>")
            }
        }
        append("</table>")
        
        // Legend
        append("<div style='margin-top: 10px;'><b>Resources:</b> ")
        data.resources.forEach { res ->
            val color = resourceColors[res.id] ?: "#e0e0e0"
            val initials = res.name.split(" ").map { it.first() }.joinToString("")
            append("<span style='display: inline-block; padding: 2px 8px; margin: 2px; background: $color; border-radius: 3px;'>$initials - ${res.name}</span>")
        }
        append("</div></div>")
    }
    
    DISPLAY(HTML(html))
} else {
    println("No solution to visualize")
}
// Out:
// <div style='font-family: -apple-system, BlinkMacSystemFont, sans-serif;'><h4>Project Calendar</h4><table style='border-collapse: collapse; font-size: 11px;'><tr><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa;'>Project</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa;'>Activity</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 45px;'>MON<br/>9/22</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 45px;'>TUE<br/>9/23</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 45px;'>WED<br/>9/24</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 45px;'>THU<br/>9/25</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 45px;'>FRI<br/>9/26</th><th style='border: 1px solid #ddd; padding: 4px; background: #f8f9fa; min-width: 45px;'>MON<br/>9/29</th><th style='border: 1px solid #ddd; padd
// ...

// %%
// Margin Analysis Table visualization
if (rcpspResult.hasSolution) {
    data class MarginAssignment(val resourceIdx: Long, val activityId: Long, val projectId: Long)
    
    val marginAssignments = workUnits.map { unit ->
        MarginAssignment(
            rcpspResult.scope.value(rcpspResult.variables["res_${unit.id}"]!!).getOrNull()!!,
            unit.activityId,
            unit.projectId
        )
    }
    
    data class ActivityMargin(
        val activity: Activity, val project: Project?, val hours: Int,
        val revenue: Double, val cost: Double, val margin: Double, val marginPct: Double
    )
    
    val activityMargins = data.activities.map { activity ->
        val actAssignments = marginAssignments.filter { it.activityId == activity.id }
        val hours = actAssignments.size
        val revenue = activity.rate * hours
        val cost = actAssignments.sumOf { assignment ->
            val resource = data.resources.getOrNull(assignment.resourceIdx.toInt())
            val position = resource?.positionId?.let { positionById[it] }
            position?.hourlyRate ?: 50.0
        }
        val margin = revenue - cost
        val marginPct = if (revenue > 0) (margin / revenue) * 100 else 0.0
        ActivityMargin(activity, projectById[activity.projectId], hours, revenue, cost, margin, marginPct)
    }
    
    data class ProjectMargin(val project: Project, val hours: Int, val revenue: Double, val cost: Double, val margin: Double, val marginPct: Double)
    
    val projectMargins = data.projects.map { project ->
        val projMargins = activityMargins.filter { it.project?.id == project.id }
        val hours = projMargins.sumOf { it.hours }
        val revenue = projMargins.sumOf { it.revenue }
        val cost = projMargins.sumOf { it.cost }
        val margin = revenue - cost
        val marginPct = if (revenue > 0) (margin / revenue) * 100 else 0.0
        ProjectMargin(project, hours, revenue, cost, margin, marginPct)
    }
    
    val totalRevenue = activityMargins.sumOf { it.revenue }
    val totalCost = activityMargins.sumOf { it.cost }
    val totalMargin = totalRevenue - totalCost
    val totalMarginPct = if (totalRevenue > 0) (totalMargin / totalRevenue) * 100 else 0.0
    
    fun marginColor(value: Double) = if (value >= 0) "#27ae60" else "#e74c3c"
    
    val html = buildString {
        append("<div style='font-family: -apple-system, BlinkMacSystemFont, sans-serif;'>")
        
        // Summary box
        append("<div style='background: linear-gradient(135deg, #3498db, #2980b9); color: white; padding: 15px; border-radius: 8px; margin-bottom: 15px; display: flex; gap: 30px;'>")
        listOf(
            "%.0f".format(totalRevenue) to "Total Revenue",
            "%.0f".format(totalCost) to "Total Cost",
            "%.0f".format(totalMargin) to "Total Margin",
            "%.1f%%".format(totalMarginPct) to "Margin %",
            workUnits.size.toString() to "Total Hours"
        ).forEach { (value, label) ->
            append("<div style='text-align: center;'>")
            append("<div style='font-size: 24px; font-weight: bold;'>$value</div>")
            append("<div style='font-size: 11px; opacity: 0.9;'>$label</div>")
            append("</div>")
        }
        append("</div>")
        
        append("<h4>Margin Analysis by Project & Activity</h4>")
        append("<table style='border-collapse: collapse; font-size: 12px; width: 100%;'>")
        
        // Header
        append("<tr>")
        listOf("Project / Activity", "Hours", "Rate", "Revenue", "Cost", "Margin", "Margin %").forEach { col ->
            append("<th style='border: 1px solid #ddd; padding: 8px; background: linear-gradient(135deg, #2c3e50, #34495e); color: white;'>$col</th>")
        }
        append("</tr>")
        
        // Project and activity rows
        projectMargins.forEach { pm ->
            append("<tr style='background: #e8f4f8; font-weight: bold;'>")
            append("<td style='border: 1px solid #ddd; padding: 8px;'><b>${pm.project.projectCode}</b> - ${pm.project.name}</td>")
            append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${pm.hours}</td>")
            append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right;'>-</td>")
            append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${"%.0f".format(pm.revenue)}</td>")
            append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${"%.0f".format(pm.cost)}</td>")
            append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace; color: ${marginColor(pm.margin)};'>${"%.0f".format(pm.margin)}</td>")
            append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace; color: ${marginColor(pm.margin)};'>${"%.1f%%".format(pm.marginPct)}</td>")
            append("</tr>")
            
            activityMargins.filter { it.project?.id == pm.project.id }.forEach { am ->
                append("<tr>")
                append("<td style='border: 1px solid #ddd; padding: 8px; padding-left: 25px;'>${am.activity.code} - ${am.activity.name}</td>")
                append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${am.hours}</td>")
                append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${"%.0f".format(am.activity.rate)}</td>")
                append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${"%.0f".format(am.revenue)}</td>")
                append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${"%.0f".format(am.cost)}</td>")
                append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace; color: ${marginColor(am.margin)};'>${"%.0f".format(am.margin)}</td>")
                append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace; color: ${marginColor(am.margin)};'>${"%.1f%%".format(am.marginPct)}</td>")
                append("</tr>")
            }
        }
        
        // Total row
        append("<tr style='background: linear-gradient(135deg, #27ae60, #2ecc71); color: white; font-weight: bold;'>")
        append("<td style='border: 1px solid #ddd; padding: 8px;'>TOTAL</td>")
        append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${workUnits.size}</td>")
        append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right;'>-</td>")
        append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${"%.0f".format(totalRevenue)}</td>")
        append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${"%.0f".format(totalCost)}</td>")
        append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${"%.0f".format(totalMargin)}</td>")
        append("<td style='border: 1px solid #ddd; padding: 8px; text-align: right; font-family: monospace;'>${"%.1f%%".format(totalMarginPct)}</td>")
        append("</tr>")
        
        append("</table></div>")
    }
    
    DISPLAY(HTML(html))
} else {
    println("No solution to visualize")
}
// Out:
// <div style='font-family: -apple-system, BlinkMacSystemFont, sans-serif;'><div style='background: linear-gradient(135deg, #3498db, #2980b9); color: white; padding: 15px; border-radius: 8px; margin-bottom: 15px; display: flex; gap: 30px;'><div style='text-align: center;'><div style='font-size: 24px; font-weight: bold;'>104005</div><div style='font-size: 11px; opacity: 0.9;'>Total Revenue</div></div><div style='text-align: center;'><div style='font-size: 24px; font-weight: bold;'>49950</div><div style='font-size: 11px; opacity: 0.9;'>Total Cost</div></div><div style='text-align: center;'><div style='font-size: 24px; font-weight: bold;'>54055</div><div style='font-size: 11px; opacity: 0.9;'>Total Margin</div></div><div style='text-align: center;'><div style='font-size: 24px; font-weight: bold;'>52,0%</div><div style='font-size: 11px; opacity: 0.9;'>Margin %</div></div><div style='text-align: center;'><div style='font-size: 24px; font-weight: bold;'>638</div><div style='font-size: 11px; 
// ...
